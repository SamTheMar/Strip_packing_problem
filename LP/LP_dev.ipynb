# %%
# %cd -0
# %cd ..
from common.utils import visualize_from_file
import matplotlib.pyplot as plt
import os
# Out:
# c:\Users\studu\Desktop\Strip_packing_problem\LP
# c:\Users\studu\Desktop\Strip_packing_problem

# %%
output_url = "test.txt"
visualize_from_file(output_url)
plt.show()

# %%
#instance_num = 3
for instance_num in range(3, 4):
    output_url = f"./LP/out/no_rotation/txt/ins-{instance_num}-sol.txt"
    if os.path.exists(output_url):
        visualize_from_file(output_url, additional_info= str(instance_num))
        plt.show()
    else:
        print(instance_num , "no solution")
